# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# c:\Users\Vei Vei\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
from ta import add_all_ta_features
from ta.utils import dropna

# %%
stock_data = pd.read_csv('GOOG.csv',index_col='Date')
stock_data
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-01-11  55.314999  55.326248  54.979500  55.276001  55.276001  19566000
# 2018-01-12  55.120499  56.214500  55.057499  56.112999  56.112999  34410000
# 2018-01-16  56.625500  56.995499  55.891602  56.088001  56.088001  31506000
# 2018-01-17  56.311001  56.630001  55.850498  56.598999  56.598999  24052000
# 2018-01-18  56.570499  56.625500  55.875000  56.489498  56.489498  23964000
# ...               ...        ...        ...        ...        ...       ...
# 2023-01-04  91.010002  91.239998  87.800003  88.709999  88.709999  27046500
# 2023-01-05  88.070000  88.209999  86.559998  86.769997  86.769997  23136100
# 2023-01-06  87.360001  88.470001  85.570000  88.160004  88.160004  26604400
# 2023-01-09  89.195000  90.830002  88.580002  88.800003  88.800003  22996700
# 2023-01-10  86.720001  89.474998  86.699997  89.239998  89.239998  22846300
#
# [1258 rows x 6 columns]

# %%
df = add_all_ta_features(
    stock_data, open="Open", high="High", low="Low", close="Close", volume="Volume")
# Out:
# c:\Users\Vei Vei\anaconda3\lib\site-packages\ta\trend.py:730: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   self._trs[0] = diff_directional_movement.dropna()[
# c:\Users\Vei Vei\anaconda3\lib\site-packages\ta\trend.py:780: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# c:\Users\Vei Vei\anaconda3\lib\site-packages\ta\trend.py:785: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)

# %%
df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-11  55.314999  55.326248  54.979500  55.276001  55.276001  19566000
# 2018-01-12  55.120499  56.214500  55.057499  56.112999  56.112999  34410000
# 2018-01-16  56.625500  56.995499  55.891602  56.088001  56.088001  31506000
# 2018-01-17  56.311001  56.630001  55.850498  56.598999  56.598999  24052000
# 2018-01-18  56.570499  56.625500  55.875000  56.489498  56.489498  23964000
# ...               ...        ...        ...        ...        ...       ...
# 2023-01-04  91.010002  91.239998  87.800003  88.709999  88.709999  27046500
# 2023-01-05  88.070000  88.209999  86.559998  86.769997  86.769997  23136100
# 2023-01-06  87.360001  88.470001  85.570000  88.160004  88.160004  26604400
# 2023-01-09  89.195000  90.830002  88.580002  88.800003  88.800003  22996700
# 2023-01-10  86.720001  89.474998  86.699997  89.239998  89.239998  22846300
#
#               volume_adi  volume_obv  volume_cmf     volume_fi  ...  \
# Date                                                            ...
# 2018-01-11  1.389541e+07    19566000         NaN           NaN  ...
# 2018-01-12  4.226799e+07    53976000         NaN           NaN  ...
# 2018-01-16  2.197272e+07    22470000         NaN           NaN  ...
# 2018-01-17  4.411156e+07    46522000         NaN           NaN  ...
# 2018-01-18  5.939027e+07    22558000         NaN           NaN  ...
# ...                  ...         ...         ...           ...  ...
# 2023-01-04  8.346381e+08  1184943900   -0.216589 -5.184483e+06  ...
# 2023-01-05  8.173912e+08  1161807800   -0.221787 -1.085585e+07  ...
# 2023-01-06  8.383078e+08  1188412200   -0.130318 -4.022118e+06  ...
# 2023-01-09  8.198083e+08  1211408900   -0.124042 -1.344977e+06  ...
# 2023-01-10  8.387851e+08  1234255200   -0.042847  2.831992e+05  ...
#
#             momentum_ppo  momentum_ppo_signal  momentum_ppo_hist  \
# Date
# 2018-01-11           NaN                  NaN                NaN
# 2018-01-12           NaN                  NaN                NaN
# 2018-01-16           NaN                  NaN                NaN
# 2018-01-17           NaN                  NaN                NaN
# 2018-01-18           NaN                  NaN                NaN
# ...                  ...                  ...                ...
# 2023-01-04     -2.203422            -2.093551          -0.109871
# 2023-01-05     -2.305211            -2.135883          -0.169328
# 2023-01-06     -2.236191            -2.155944          -0.080247
# 2023-01-09     -2.099875            -2.144731           0.044856
# 2023-01-10     -1.929929            -2.101770           0.171841
#
#             momentum_pvo  momentum_pvo_signal  momentum_pvo_hist  \
# Date
# 2018-01-11           NaN                  NaN                NaN
# 2018-01-12           NaN                  NaN                NaN
# 2018-01-16           NaN                  NaN                NaN
# 2018-01-17           NaN                  NaN                NaN
# 2018-01-18           NaN                  NaN                NaN
# ...                  ...                  ...                ...
# 2023-01-04     -6.075264            -5.982674          -0.092590
# 2023-01-05     -5.318321            -5.849803           0.531482
# 2023-01-06     -3.452315            -5.370306           1.917990
# 2023-01-09     -3.206195            -4.937484           1.731288
# 2023-01-10     -3.028997            -4.555786           1.526790
#
#             momentum_kama  others_dr  others_dlr  others_cr
# Date
# 2018-01-11            NaN -35.839816         NaN   0.000000
# 2018-01-12            NaN   1.514216    1.502866   1.514216
# 2018-01-16            NaN  -0.044549   -0.044559   1.468992
# 2018-01-17            NaN   0.911065    0.906940   2.393440
# 2018-01-18            NaN  -0.193468   -0.193655   2.195342
# ...                   ...        ...         ...        ...
# 2023-01-04      90.386127  -1.103677   -1.109812  60.485559
# 2023-01-05      90.260374  -2.186903   -2.211171  56.975894
# 2023-01-06      90.213722   1.601944    1.589249  59.490561
# 2023-01-09      90.202642   0.725952    0.723329  60.648385
# 2023-01-10      90.194471   0.495490    0.494266  61.444382
#
# [1258 rows x 92 columns]

# %%
df=df.fillna(value=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1258 entries, 2018-01-11 to 2023-01-10
# Data columns (total 92 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Open                       1258 non-null   float64
#  1   High                       1258 non-null   float64
#  2   Low                        1258 non-null   float64
#  3   Close                      1258 non-null   float64
#  4   Adj Close                  1258 non-null   float64
#  5   Volume                     1258 non-null   int64
#  6   volume_adi                 1258 non-null   float64
#  7   volume_obv                 1258 non-null   int64
#  8   volume_cmf                 1258 non-null   float64
#  9   volume_fi                  1258 non-null   float64
#  10  volume_em                  1258 non-null   float64
#  11  volume_sma_em              1258 non-null   float64
#  12  volume_vpt                 1258 non-null   float64
#  13  volume_vwap                1258 non-null   float64
#  14  volume_mfi                 1258 non-null   float64
#  15  volume_nvi                 1258 non-null   float64
#  16  volatility_bbm             1258 non-null   float64
#  17  volatility_bbh             1258 non-null   float64
#  18  volatility_bbl             1258 non-null   float64
#  19  volatility_bbw             1258 non-null   float64
#  20  volatility_bbp             1258 non-null   float64
#  21  volatility_bbhi            1258 non-null   float64
#  22  volatility_bbli            1258 non-null   float64
#  23  volatility_kcc             1258 non-null   float64
#  24  volatility_kch             1258 non-null   float64
#  25  volatility_kcl             1258 non-null   float64
#  26  volatility_kcw             1258 non-null   float64
#  27  volatility_kcp             1258 non-null   float64
#  28  volatility_kchi            1258 non-null   float64
#  29  volatility_kcli            1258 non-null   float64
#  30  volatility_dcl             1258 non-null   float64
#  31  volatility_dch             1258 non-null   float64
#  32  volatility_dcm             1258 non-null   float64
#  33  volatility_dcw             1258 non-null   float64
#  34  volatility_dcp             1258 non-null   float64
#  35  volatility_atr             1258 non-null   float64
#  36  volatility_ui              1258 non-null   float64
#  37  trend_macd                 1258 non-null   float64
#  38  trend_macd_signal          1258 non-null   float64
#  39  trend_macd_diff            1258 non-null   float64
#  40  trend_sma_fast             1258 non-null   float64
#  41  trend_sma_slow             1258 non-null   float64
#  42  trend_ema_fast             1258 non-null   float64
#  43  trend_ema_slow             1258 non-null   float64
#  44  trend_vortex_ind_pos       1258 non-null   float64
#  45  trend_vortex_ind_neg       1258 non-null   float64
#  46  trend_vortex_ind_diff      1258 non-null   float64
#  47  trend_trix                 1258 non-null   float64
#  48  trend_mass_index           1258 non-null   float64
#  49  trend_dpo                  1258 non-null   float64
#  50  trend_kst                  1258 non-null   float64
#  51  trend_kst_sig              1258 non-null   float64
#  52  trend_kst_diff             1258 non-null   float64
#  53  trend_ichimoku_conv        1258 non-null   float64
#  54  trend_ichimoku_base        1258 non-null   float64
#  55  trend_ichimoku_a           1258 non-null   float64
#  56  trend_ichimoku_b           1258 non-null   float64
#  57  trend_stc                  1258 non-null   float64
#  58  trend_adx                  1258 non-null   float64
#  59  trend_adx_pos              1258 non-null   float64
#  60  trend_adx_neg              1258 non-null   float64
#  61  trend_cci                  1258 non-null   float64
#  62  trend_visual_ichimoku_a    1258 non-null   float64
#  63  trend_visual_ichimoku_b    1258 non-null   float64
#  64  trend_aroon_up             1258 non-null   float64
#  65  trend_aroon_down           1258 non-null   float64
#  66  trend_aroon_ind            1258 non-null   float64
#  67  trend_psar_up              1258 non-null   float64
#  68  trend_psar_down            1258 non-null   float64
#  69  trend_psar_up_indicator    1258 non-null   float64
#  70  trend_psar_down_indicator  1258 non-null   float64
#  71  momentum_rsi               1258 non-null   float64
#  72  momentum_stoch_rsi         1258 non-null   float64
#  73  momentum_stoch_rsi_k       1258 non-null   float64
#  74  momentum_stoch_rsi_d       1258 non-null   float64
#  75  momentum_tsi               1258 non-null   float64
#  76  momentum_uo                1258 non-null   float64
#  77  momentum_stoch             1258 non-null   float64
#  78  momentum_stoch_signal      1258 non-null   float64
#  79  momentum_wr                1258 non-null   float64
#  80  momentum_ao                1258 non-null   float64
#  81  momentum_roc               1258 non-null   float64
#  82  momentum_ppo               1258 non-null   float64
#  83  momentum_ppo_signal        1258 non-null   float64
#  84  momentum_ppo_hist          1258 non-null   float64
#  85  momentum_pvo               1258 non-null   float64
#  86  momentum_pvo_signal        1258 non-null   float64
#  87  momentum_pvo_hist          1258 non-null   float64
#  88  momentum_kama              1258 non-null   float64
#  89  others_dr                  1258 non-null   float64
#  90  others_dlr                 1258 non-null   float64
#  91  others_cr                  1258 non-null   float64
# dtypes: float64(90), int64(2)
# memory usage: 946.3+ KB

# %%
def LSTM_Predict_Model(data, Period, Win, Pca):
    ## PCA
    if  Pca:
        from sklearn.decomposition import PCA
        pca = PCA(n_components=10)
        HLOCAV = data.iloc[:,:5]
        ## reset the index to match tech_indicator
        HLOCAV.index=list(range(len(data)))
        tech_factor = data.iloc[:,6:]
        tech_pca = pd.DataFrame(pca.fit_transform(tech_factor))
        data = pd.concat([HLOCAV,tech_pca],axis=1)
    
    ## Data processing
    train_total = data.iloc[:-Period]
    X_test = data.iloc[-Period:] #test last 400 days
    Y_test = data.iloc[-Period:,4] ## The forth column is the adj-close, which is the target
    
    ## Min Max Normalization-----training set
    from sklearn.preprocessing import MinMaxScaler
    sc = MinMaxScaler(feature_range = (0, 1))
    sc1 = MinMaxScaler(feature_range = (0, 1))
    data_scaled = sc.fit_transform(train_total) 
    
    target_scaled = sc1.fit_transform(np.array(data.iloc[:-Period,4]).reshape(-1,1)) 
    target_scaled_mean = target_scaled.mean()
    
    ## zero_mean
    col = data_scaled.shape[0]
    mean_array = np.mean(data_scaled, axis=0)
    mean_matrix = np.tile(mean_array, (col,1))
    data_scaled -= mean_matrix
    target_scaled -= target_scaled_mean
    
    ## Split training featfures and target
    X_train_n = data_scaled.copy()
    Y_train_n = target_scaled
    X_train = []
    y_train = []
    for i in range(Win, len(X_train_n)):
        X_train.append(X_train_n[i-Win:i, :])
        y_train.append(Y_train_n[i, ])  
    X_train, y_train = np.array(X_train), np.array(y_train)
    feature_nums = data.shape[1]
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], feature_nums))


    ## LSTM model
    from keras.models import Sequential
    from keras.layers import Dense
    from keras.layers import LSTM
    from keras.layers import Dropout
    
    regressor = Sequential()
    ## input matrices intialization method Glorot Uniform
    regressor.add(LSTM(units = 50, return_sequences = True,kernel_initializer="glorot_normal",input_shape = (X_train.shape[1], feature_nums)))
    regressor.add(Dropout(0.2))
    ## recurrent matrices intialization method Orthogonal 
    regressor.add(LSTM(units = 50,kernel_initializer="Orthogonal"))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units = 1))
    
    print("For Test Period = "+str(Period))
    regressor.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['mae','mape'])
    regressor.fit(X_train, y_train, epochs = 10, batch_size = 32)
    
    ### Test Data
    dataset_total = np.concatenate((train_total,X_test),axis=0)
    inputs = dataset_total[len(dataset_total) - len(X_test) - Win:]
    
    ## transform the test data
    inputs = sc.transform(inputs)
    test_col = inputs.shape[0]
    mean_matrix2 = np.tile(mean_array, (test_col,1))
    inputs -= mean_matrix2
       
    X_test_set = []
    for i in range(Win, len(inputs)):
        X_test_set.append(inputs[i-Win:i, :])
    X_test_set = np.array(X_test_set)
    X_test_set = np.reshape(X_test_set, (X_test_set.shape[0], X_test_set.shape[1], feature_nums))
    
    ## Get the transformed Y_test to Evaluate the Model
    Y_test_scaled=sc1.transform(np.array(Y_test).reshape(-1,1))
    Y_test_scaled =Y_test_scaled - target_scaled_mean
    
    ## Evaluate the Model
    evaluation = regressor.evaluate(X_test_set,Y_test_scaled,batch_size=32)

    print("\n-----Model Evaluation Result of "+str(Period)+" Days Testing Period-----\n")
    print("Loss value:",evaluation[0])
    print("MAE:",evaluation[1])
    print("MAPE:",evaluation[2])
    print("\n")
    
    
    ##Get the predicted result
    predicted_stock_price = regressor.predict(X_test_set)
    
    ## re-transform the predicted value
    predicted_stock_price += target_scaled_mean
    predicted_stock_price = sc1.inverse_transform(predicted_stock_price)
    
    ## real price
    real_stock_price = np.array(Y_test)
    return [[real_stock_price,predicted_stock_price],evaluation]

# %%
A = LSTM_Predict_Model(df, 400, 30, False)
B = LSTM_Predict_Model(df, 400, 30, True)
# Out:
# For Test Period = 400
# Epoch 1/10
# 26/26 [==============================] - 11s 45ms/step - loss: 0.0055 - mae: 0.0538 - mape: 75.7442
# Epoch 2/10
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0025 - mae: 0.0366 - mape: 53.2362
# Epoch 3/10
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0019 - mae: 0.0335 - mape: 51.4347
# Epoch 4/10
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0016 - mae: 0.0300 - mape: 43.3391
# Epoch 5/10
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0015 - mae: 0.0284 - mape: 43.3049
# Epoch 6/10
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0013 - mae: 0.0276 - mape: 35.5314
# Epoch 7/10
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0012 - mae: 0.0257 - mape: 31.2714
# Epoch 8/10
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0013 - mae: 0.0269 - mape: 30.3995
# Epoch 9/10
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0013 - mae: 0.0265 - mape: 36.2889
# Epoch 10/10
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0013 - mae: 0.0264 - mape: 30.6156
# c:\Users\Vei Vei\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 13/13 [==============================] - 3s 25ms/step - loss: 0.0096 - mae: 0.0831 - mape: 12.8683
#
# -----Model Evaluation Result of 400 Days Testing Period-----
#
# Loss value: 0.009553086012601852
# MAE: 0.08313227444887161
# MAPE: 12.868273735046387
#
#
# 13/13 [==============================] - 2s 19ms/step
# c:\Users\Vei Vei\anaconda3\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# c:\Users\Vei Vei\anaconda3\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# For Test Period = 400
# Epoch 1/10
# 26/26 [==============================] - 12s 53ms/step - loss: 0.0103 - mae: 0.0649 - mape: 57.1577
# Epoch 2/10
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0022 - mae: 0.0348 - mape: 42.5396
# Epoch 3/10
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0020 - mae: 0.0330 - mape: 37.7973
# Epoch 4/10
# 26/26 [==============================] - 1s 38ms/step - loss: 0.0016 - mae: 0.0286 - mape: 35.9278
# Epoch 5/10
# 26/26 [==============================] - 1s 37ms/step - loss: 0.0014 - mae: 0.0273 - mape: 33.3331
# Epoch 6/10
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0015 - mae: 0.0279 - mape: 32.4045
# Epoch 7/10
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0015 - mae: 0.0281 - mape: 34.1139
# Epoch 8/10
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0014 - mae: 0.0273 - mape: 35.0318
# Epoch 9/10
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0013 - mae: 0.0261 - mape: 31.4050
# Epoch 10/10
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0012 - mae: 0.0252 - mape: 30.1351
# 13/13 [==============================] - 2s 16ms/step - loss: 0.0035 - mae: 0.0486 - mape: 8.1847
#
# -----Model Evaluation Result of 400 Days Testing Period-----
#
# Loss value: 0.0035426001995801926
# MAE: 0.04863489791750908
# MAPE: 8.184653282165527
#
#
# 13/13 [==============================] - 2s 15ms/step

# %%
ModelA=[]
ModelB=[]
ModelA.append(A)
ModelB.append(B)

# %%
import seaborn as sns
c1, c2, c3,c4,c5 = sns.color_palette("pastel", 5)
fig = plt.figure(figsize=[12,24])
ax1 = fig.add_subplot(411)
ax1 = fig.add_subplot(411)
ax1.plot(ModelA[0][0][0], color = c1, label = 'Real GOOG Stock Price')
ax1.plot(ModelA[0][0][1], color = c3, label = 'Predicted GOOG Stock Price')
ax1.plot(ModelB[0][0][1], color = c2, label = 'Predicted GOOG Stock Price with PCA')
ax1.set_title('GOOG Stock Prediction result series chart of 400 days')
ax1.set_xlabel('Time')
ax1.set_ylabel('GOOG Stock Price')
ax1.legend()
# Out:
# C:\Users\VEIVEI~1\AppData\Local\Temp/ipykernel_16428/2216558657.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1 = fig.add_subplot(411)

# %%
fig1= plt.figure(figsize=[8,8])
ax2 = fig1.add_subplot(111)
    
MAE=[ModelA[0][1][1],ModelB[0][1][1]]
    
ax2.bar(["MAE","MAE-PCA"],MAE, color=c3, width=0.8,label = 'Mean Absolute Error')
ax2.set_title('Bar Graph of Mean Absolute Error')
ax2.set_xlabel('Test Period')
ax2.set_ylabel('Mean Absolute Error')
ax2.legend()
plt.show()

# %%
fig2= plt.figure(figsize=[8,8])
ax5 = fig2.add_subplot(111)
    
MAPE=[ModelA[0][1][2],ModelB[0][1][2]]
    
ax5.bar(["MAPE","MAPE-PCA"],MAPE, color=c4, width=0.8,label = 'Mean Absolute Percentage Error')
ax5.set_title('Mean Absolute Percentage Error')
ax5.set_xlabel('Test Period')
ax5.set_ylabel('Bar Graph of Mean Absolute Percentage Error')
ax5.legend()
